# %%
# %%capture
# !pip install --upgrade datasets

# %%
from datasets import load_dataset

# 데이터를 로드합니다.
data = load_dataset("rotten_tomatoes")
data
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# train.parquet:   0%|          | 0.00/699k [00:00<?, ?B/s]
# validation.parquet:   0%|          | 0.00/90.0k [00:00<?, ?B/s]
# test.parquet:   0%|          | 0.00/92.2k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8530 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1066 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1066 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 8530
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1066
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1066
#     })
# })

# %%
data["train"][0,-1]
# Out:
# {'text': ['the rock is destined to be the 21st century\'s new " conan " and that he\'s going to make a splash even greater than arnold schwarzenegger , jean-claud van damme or steven segal .',
#   'things really get weird , though not particularly scary : the movie is all portent and no content .'],
#  'label': [1, 0]}

# %%
from transformers import pipeline

model_path = "cardiffnlp/twitter-roberta-base-sentiment-latest"

pipe = pipeline(
    model = model_path,
    return_all_scores = True,
    device = "cuda:0"
)
# Out:
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# vocab.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/501M [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use cuda:0
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
import numpy as np
from tqdm import tqdm
from transformers.pipelines.pt_utils import KeyDataset

# 추론을 실행합니다.
y_pred = []
for output in tqdm(pipe(KeyDataset(data["test"], "text")), total=len(data["test"])):
    print(output)
    negative_score = output[0]["score"]
    positive_score = output[2]["score"]
    assignment = np.argmax([negative_score, positive_score])
    y_pred.append(assignment)
# Out:
#   1%|          | 11/1066 [00:00<00:10, 101.93it/s]
# [{'label': 'negative', 'score': 0.00516123790293932}, {'label': 'neutral', 'score': 0.040233541280031204}, {'label': 'positive', 'score': 0.9546052813529968}]
# [{'label': 'negative', 'score': 0.007706415373831987}, {'label': 'neutral', 'score': 0.10390986502170563}, {'label': 'positive', 'score': 0.8883837461471558}]
# [{'label': 'negative', 'score': 0.7359187006950378}, {'label': 'neutral', 'score': 0.242427259683609}, {'label': 'positive', 'score': 0.021654030308127403}]
# [{'label': 'negative', 'score': 0.0030380741227418184}, {'label': 'neutral', 'score': 0.06267126649618149}, {'label': 'positive', 'score': 0.9342906475067139}]
# [{'label': 'negative', 'score': 0.11185657232999802}, {'label': 'neutral', 'score': 0.7006849646568298}, {'label': 'positive', 'score': 0.18745848536491394}]
# [{'label': 'negative', 'score': 0.6089203357696533}, {'label': 'neutral', 'score': 0.3732679784297943}, {'label': 'positive', 'score': 0.01781175285577774}]
# [{'label': 'negative', 'score': 0.02079029008746147}, {'label': 'neutral', 'score': 0.45805108547210693}, {'label': 'positive', 'score': 0.5211586356163025}]
# [{'label': 'negative', 'score': 0.009388197213411331}, {'label': 'neutral', 'score': 0.1562182754278183}, {'label': 'positive', 'score': 0.8343935608863831}]
# [{'label': 'negative', 'score': 0.009773926809430122}, {'label': 'neutral', 'score': 0.1858532875776291}, {'label': 'positive', 'score': 0.8043728470802307}]
# [{'label': 'negative', 'score': 0.02712368220090866}, {'label': 'neutral', 'score': 0.37884238362312317}, {'label': 'positive', 'score': 0.59403395652771}]
# [{'label': 'negative', 'score': 0.27410000562667847}, {'label': 'neutral', 'score': 0.5992848873138428}, {'label': 'positive', 'score': 0.12661507725715637}]
# [{'label': 'negative', 'score': 0.8024448156356812}, {'label': 'neutral', 'score': 0.1860198974609375}, {'label': 'positive', 'score': 0.01153529155999422}]
# [{'label': 'negative', 'score': 0.6360161900520325}, {'label': 'neutral', 'score': 0.3486211895942688}, {'label': 'positive', 'score': 0.015362627804279327}]
# [{'label': 'negative', 'score': 0.007529248483479023}, {'label': 'neutral', 'score': 0.15941248834133148}, {'label': 'positive', 'score': 0.8330582976341248}]
# [{'label': 'negative', 'score': 0.9433056712150574}, {'label': 'neutral', 'score': 0.05138496682047844}, {'label': 'positive', 'score': 0.005309318192303181}]
# [{'label': 'negative', 'score': 0.03347816690802574}, {'label': 'neutral', 'score': 0.15110312402248383}, {'label': 'positive', 'score': 0.8154187202453613}]
# [{'label': 'negative', 'score': 0.021312450990080833}, {'label': 'neutral', 'score': 0.29876619577407837}, {'label': 'positive', 'score': 0.6799213290214539}]
# [{'label': 'negative', 'score': 0.005375251639634371}, {'label': 'neutral', 'score': 0.09685274213552475}, {'label': 'positive', 'score': 0.897771954536438}]
# [{'label': 'negative', 'score': 0.017783939838409424}, {'label': 'neutral', 'score': 0.6452141404151917}, {'label': 'positive', 'score': 0.33700188994407654}]
# [{'label': 'negative', 'score': 0.00323072774335742}, {'label': 'neutral', 'score': 0.07248532772064209}, {'label': 'positive', 'score': 0.9242839813232422}]
#   3%|▎         | 33/1066 [00:00<00:10, 99.66it/s]
# [{'label': 'negative', 'score': 0.017986487597227097}, {'label': 'neutral', 'score': 0.22880437970161438}, {'label': 'positive', 'score': 0.7532091736793518}]
# [{'label': 'negative', 'score': 0.6301175355911255}, {'label': 'neutral', 'score': 0.3416175842285156}, {'label': 'positive', 'score': 0.02826482057571411}]
# [{'label': 'negative', 'score': 0.37610670924186707}, {'label': 'neutral', 'score': 0.5443652272224426}, {'label': 'positive', 'score': 0.0795280784368515}]
# [{'label': 'negative', 'score': 0.11886264383792877}, {'label': 'neutral', 'score': 0.7047324776649475}, {'label': 'positive', 'score': 0.1764049381017685}]
# [{'label': 'negative', 'score': 0.006460942793637514}, {'label': 'neutral', 'score': 0.04016125574707985}, {'label': 'positive', 'score': 0.9533777832984924}]
# [{'label': 'negative', 'score': 0.9284610748291016}, {'label': 'neutral', 'score': 0.06647174060344696}, {'label': 'positive', 'score': 0.005067161284387112}]
# [{'label': 'negative', 'score': 0.019999239593744278}, {'label': 'neutral', 'score': 0.1309157907962799}, {'label': 'positive', 'score': 0.8490849733352661}]
# [{'label': 'negative', 'score': 0.08965035527944565}, {'label': 'neutral', 'score': 0.23907236754894257}, {'label': 'positive', 'score': 0.6712772846221924}]
# [{'label': 'negative', 'score': 0.6741817593574524}, {'label': 'neutral', 'score': 0.28780385851860046}, {'label': 'positive', 'score': 0.03801444172859192}]
# [{'label': 'negative', 'score': 0.03508107736706734}, {'label': 'neutral', 'score': 0.6752836108207703}, {'label': 'positive', 'score': 0.2896353006362915}]
# [{'label': 'negative', 'score': 0.026973262429237366}, {'label': 'neutral', 'score': 0.238075390458107}, {'label': 'positive', 'score': 0.7349513173103333}]
# [{'label': 'negative', 'score': 0.5658921599388123}, {'label': 'neutral', 'score': 0.39300239086151123}, {'label': 'positive', 'score': 0.041105449199676514}]
# [{'label': 'negative', 'score': 0.0038657630793750286}, {'label': 'neutral', 'score': 0.018277490511536598}, {'label': 'positive', 'score': 0.9778568148612976}]
# [{'label': 'negative', 'score': 0.020902732387185097}, {'label': 'neutral', 'score': 0.16473203897476196}, {'label': 'positive', 'score': 0.8143652081489563}]
# [{'label': 'negative', 'score': 0.010330351069569588}, {'label': 'neutral', 'score': 0.06858718395233154}, {'label': 'positive', 'score': 0.9210824370384216}]
# [{'label': 'negative', 'score': 0.03833687677979469}, {'label': 'neutral', 'score': 0.2148401439189911}, {'label': 'positive', 'score': 0.7468230128288269}]
# [{'label': 'negative', 'score': 0.3054850101470947}, {'label': 'neutral', 'score': 0.6537953615188599}, {'label': 'positive', 'score': 0.0407196469604969}]
# [{'label': 'negative', 'score': 0.004782760050147772}, {'label': 'neutral', 'score': 0.01715654507279396}, {'label': 'positive', 'score': 0.9780606627464294}]
# [{'label': 'negative', 'score': 0.047649551182985306}, {'label': 'neutral', 'score': 0.559797465801239}, {'label': 'positive', 'score': 0.3925529420375824}]
# [{'label': 'negative', 'score': 0.19740675389766693}, {'label': 'neutral', 'score': 0.5586875677108765}, {'label': 'positive', 'score': 0.2439056783914566}]
# [{'label': 'negative', 'score': 0.31281614303588867}, {'label': 'neutral', 'score': 0.624808132648468}, {'label': 'positive', 'score': 0.06237572804093361}]
#   5%|▌         | 54/1066 [00:00<00:10, 92.05it/s]
# [{'label': 'negative', 'score': 0.011581666767597198}, {'label': 'neutral', 'score': 0.21797828376293182}, {'label': 'positive', 'score': 0.7704400420188904}]
# [{'label': 'negative', 'score': 0.147379532456398}, {'label': 'neutral', 'score': 0.5063107013702393}, {'label': 'positive', 'score': 0.3463097810745239}]
# [{'label': 'negative', 'score': 0.4629756212234497}, {'label': 'neutral', 'score': 0.34093940258026123}, {'label': 'positive', 'score': 0.19608496129512787}]
# [{'label': 'negative', 'score': 0.09978976100683212}, {'label': 'neutral', 'score': 0.7821436524391174}, {'label': 'positive', 'score': 0.11806655675172806}]
# [{'label': 'negative', 'score': 0.3047122359275818}, {'label': 'neutral', 'score': 0.4484129548072815}, {'label': 'positive', 'score': 0.24687477946281433}]
# [{'label': 'negative', 'score': 0.03860998526215553}, {'label': 'neutral', 'score': 0.5789915323257446}, {'label': 'positive', 'score': 0.38239845633506775}]
# [{'label': 'negative', 'score': 0.009049108251929283}, {'label': 'neutral', 'score': 0.045412030071020126}, {'label': 'positive', 'score': 0.9455388784408569}]
# [{'label': 'negative', 'score': 0.007815418764948845}, {'label': 'neutral', 'score': 0.11364603042602539}, {'label': 'positive', 'score': 0.8785386085510254}]
# [{'label': 'negative', 'score': 0.007796997204422951}, {'label': 'neutral', 'score': 0.2009699046611786}, {'label': 'positive', 'score': 0.7912330627441406}]
# [{'label': 'negative', 'score': 0.7773857712745667}, {'label': 'neutral', 'score': 0.21240389347076416}, {'label': 'positive', 'score': 0.010210336185991764}]
# [{'label': 'negative', 'score': 0.005911027546972036}, {'label': 'neutral', 'score': 0.3430910110473633}, {'label': 'positive', 'score': 0.6509979963302612}]
# [{'label': 'negative', 'score': 0.2585769295692444}, {'label': 'neutral', 'score': 0.6864831447601318}, {'label': 'positive', 'score': 0.05493989214301109}]
# [{'label': 'negative', 'score': 0.5550523400306702}, {'label': 'neutral', 'score': 0.4173392653465271}, {'label': 'positive', 'score': 0.02760838344693184}]
# [{'label': 'negative', 'score': 0.9156798124313354}, {'label': 'neutral', 'score': 0.07883252948522568}, {'label': 'positive', 'score': 0.0054876431822776794}]
# [{'label': 'negative', 'score': 0.00412390474230051}, {'label': 'neutral', 'score': 0.0790409967303276}, {'label': 'positive', 'score': 0.9168350696563721}]
# [{'label': 'negative', 'score': 0.38045239448547363}, {'label': 'neutral', 'score': 0.4868977665901184}, {'label': 'positive', 'score': 0.132649764418602}]
# [{'label': 'negative', 'score': 0.18522359430789948}, {'label': 'neutral', 'score': 0.47725021839141846}, {'label': 'positive', 'score': 0.3375261425971985}]
# [{'label': 'negative', 'score': 0.021425990387797356}, {'label': 'neutral', 'score': 0.08906811475753784}, {'label': 'positive', 'score': 0.8895058631896973}]
# [{'label': 'negative', 'score': 0.8505584597587585}, {'label': 'neutral', 'score': 0.13850092887878418}, {'label': 'positive', 'score': 0.010940702632069588}]
#   7%|▋         | 76/1066 [00:00<00:09, 99.24it/s]
# [{'label': 'negative', 'score': 0.3471376597881317}, {'label': 'neutral', 'score': 0.5595625638961792}, {'label': 'positive', 'score': 0.09329980611801147}]
# [{'label': 'negative', 'score': 0.1383790820837021}, {'label': 'neutral', 'score': 0.5348008871078491}, {'label': 'positive', 'score': 0.3268199861049652}]
# [{'label': 'negative', 'score': 0.008906856179237366}, {'label': 'neutral', 'score': 0.06921808421611786}, {'label': 'positive', 'score': 0.9218751192092896}]
# [{'label': 'negative', 'score': 0.27170974016189575}, {'label': 'neutral', 'score': 0.6888996362686157}, {'label': 'positive', 'score': 0.03939065337181091}]
# [{'label': 'negative', 'score': 0.18909385800361633}, {'label': 'neutral', 'score': 0.7820724844932556}, {'label': 'positive', 'score': 0.02883375622332096}]
# [{'label': 'negative', 'score': 0.029483575373888016}, {'label': 'neutral', 'score': 0.3809889554977417}, {'label': 'positive', 'score': 0.5895274877548218}]
# [{'label': 'negative', 'score': 0.41154706478118896}, {'label': 'neutral', 'score': 0.5452567934989929}, {'label': 'positive', 'score': 0.043196141719818115}]
# [{'label': 'negative', 'score': 0.10857462137937546}, {'label': 'neutral', 'score': 0.5616807341575623}, {'label': 'positive', 'score': 0.3297446370124817}]
# [{'label': 'negative', 'score': 0.0685538649559021}, {'label': 'neutral', 'score': 0.4107334613800049}, {'label': 'positive', 'score': 0.520712673664093}]
# [{'label': 'negative', 'score': 0.04627422243356705}, {'label': 'neutral', 'score': 0.8667869567871094}, {'label': 'positive', 'score': 0.08693877607584}]
# [{'label': 'negative', 'score': 0.005539709236472845}, {'label': 'neutral', 'score': 0.05022042989730835}, {'label': 'positive', 'score': 0.9442398548126221}]
# [{'label': 'negative', 'score': 0.006308492738753557}, {'label': 'neutral', 'score': 0.02206370234489441}, {'label': 'positive', 'score': 0.9716278314590454}]
# [{'label': 'negative', 'score': 0.009892808273434639}, {'label': 'neutral', 'score': 0.26663923263549805}, {'label': 'positive', 'score': 0.7234679460525513}]
# [{'label': 'negative', 'score': 0.002110513858497143}, {'label': 'neutral', 'score': 0.013167818076908588}, {'label': 'positive', 'score': 0.9847217202186584}]
# [{'label': 'negative', 'score': 0.007647902239114046}, {'label': 'neutral', 'score': 0.04742966219782829}, {'label': 'positive', 'score': 0.9449223875999451}]
# [{'label': 'negative', 'score': 0.004912825766950846}, {'label': 'neutral', 'score': 0.030090466141700745}, {'label': 'positive', 'score': 0.9649966955184937}]
# [{'label': 'negative', 'score': 0.01843222603201866}, {'label': 'neutral', 'score': 0.19352246820926666}, {'label': 'positive', 'score': 0.7880452871322632}]
# [{'label': 'negative', 'score': 0.10734134167432785}, {'label': 'neutral', 'score': 0.7435782551765442}, {'label': 'positive', 'score': 0.14908047020435333}]
# [{'label': 'negative', 'score': 0.004607182927429676}, {'label': 'neutral', 'score': 0.019662747159600258}, {'label': 'positive', 'score': 0.9757300615310669}]
# [{'label': 'negative', 'score': 0.5002731680870056}, {'label': 'neutral', 'score': 0.41858208179473877}, {'label': 'positive', 'score': 0.08114471286535263}]
# [{'label': 'negative', 'score': 0.005226932466030121}, {'label': 'neutral', 'score': 0.05896221846342087}, {'label': 'positive', 'score': 0.9358108043670654}]
# [{'label': 'negative', 'score': 0.15192647278308868}, {'label': 'neutral', 'score': 0.6255757808685303}, {'label': 'positive', 'score': 0.22249776124954224}]
#   9%|▉         | 99/1066 [00:00<00:09, 104.76it/s]
# [{'label': 'negative', 'score': 0.0036470661871135235}, {'label': 'neutral', 'score': 0.08960309624671936}, {'label': 'positive', 'score': 0.9067499041557312}]
# [{'label': 'negative', 'score': 0.6298417448997498}, {'label': 'neutral', 'score': 0.3354121744632721}, {'label': 'positive', 'score': 0.03474610671401024}]
# [{'label': 'negative', 'score': 0.007816811092197895}, {'label': 'neutral', 'score': 0.1283426135778427}, {'label': 'positive', 'score': 0.8638405799865723}]
# [{'label': 'negative', 'score': 0.039708565920591354}, {'label': 'neutral', 'score': 0.5544771552085876}, {'label': 'positive', 'score': 0.40581434965133667}]
# [{'label': 'negative', 'score': 0.008983832783997059}, {'label': 'neutral', 'score': 0.047556072473526}, {'label': 'positive', 'score': 0.9434601664543152}]
# [{'label': 'negative', 'score': 0.07915183156728745}, {'label': 'neutral', 'score': 0.846429169178009}, {'label': 'positive', 'score': 0.07441902160644531}]
# [{'label': 'negative', 'score': 0.25810322165489197}, {'label': 'neutral', 'score': 0.711287796497345}, {'label': 'positive', 'score': 0.030609045177698135}]
# [{'label': 'negative', 'score': 0.04830848053097725}, {'label': 'neutral', 'score': 0.24951885640621185}, {'label': 'positive', 'score': 0.7021726369857788}]
# [{'label': 'negative', 'score': 0.13105615973472595}, {'label': 'neutral', 'score': 0.5230548977851868}, {'label': 'positive', 'score': 0.34588897228240967}]
# [{'label': 'negative', 'score': 0.005516680423170328}, {'label': 'neutral', 'score': 0.060243383049964905}, {'label': 'positive', 'score': 0.9342399835586548}]
# [{'label': 'negative', 'score': 0.13074690103530884}, {'label': 'neutral', 'score': 0.701371431350708}, {'label': 'positive', 'score': 0.16788163781166077}]
# [{'label': 'negative', 'score': 0.0030644922517240047}, {'label': 'neutral', 'score': 0.020648162811994553}, {'label': 'positive', 'score': 0.976287305355072}]
# [{'label': 'negative', 'score': 0.042810142040252686}, {'label': 'neutral', 'score': 0.131313756108284}, {'label': 'positive', 'score': 0.8258760571479797}]
# [{'label': 'negative', 'score': 0.034815315157175064}, {'label': 'neutral', 'score': 0.6846105456352234}, {'label': 'positive', 'score': 0.2805742025375366}]
# [{'label': 'negative', 'score': 0.009305845946073532}, {'label': 'neutral', 'score': 0.13147276639938354}, {'label': 'positive', 'score': 0.8592213988304138}]
# [{'label': 'negative', 'score': 0.0033629019744694233}, {'label': 'neutral', 'score': 0.04536698758602142}, {'label': 'positive', 'score': 0.9512701034545898}]
# [{'label': 'negative', 'score': 0.01169312372803688}, {'label': 'neutral', 'score': 0.11570828408002853}, {'label': 'positive', 'score': 0.8725985884666443}]
# [{'label': 'negative', 'score': 0.44284507632255554}, {'label': 'neutral', 'score': 0.531669020652771}, {'label': 'positive', 'score': 0.025485968217253685}]
# [{'label': 'negative', 'score': 0.003924360498785973}, {'label': 'neutral', 'score': 0.12982426583766937}, {'label': 'positive', 'score': 0.8662513494491577}]
# [{'label': 'negative', 'score': 0.0038276324048638344}, {'label': 'neutral', 'score': 0.07562562078237534}, {'label': 'positive', 'score': 0.9205467104911804}]
# [{'label': 'negative', 'score': 0.004468269646167755}, {'label': 'neutral', 'score': 0.04585319012403488}, {'label': 'positive', 'score': 0.9496784806251526}]
# [{'label': 'negative', 'score': 0.026214202865958214}, {'label': 'neutral', 'score': 0.15626288950443268}, {'label': 'positive', 'score': 0.8175229430198669}]
# [{'label': 'negative', 'score': 0.006228516343981028}, {'label': 'neutral', 'score': 0.10623834282159805}, {'label': 'positive', 'score': 0.8875331282615662}]
#  11%|█▏        | 121/1066 [00:01<00:09, 101.15it/s]
# [{'label': 'negative', 'score': 0.04067418724298477}, {'label': 'neutral', 'score': 0.5054827928543091}, {'label': 'positive', 'score': 0.45384299755096436}]
# [{'label': 'negative', 'score': 0.001664957613684237}, {'label': 'neutral', 'score': 0.016735197976231575}, {'label': 'positive', 'score': 0.9815998673439026}]
# [{'label': 'negative', 'score': 0.6975506544113159}, {'label': 'neutral', 'score': 0.28685101866722107}, {'label': 'positive', 'score': 0.015598395839333534}]
# [{'label': 'negative', 'score': 0.004893415607511997}, {'label': 'neutral', 'score': 0.015543251298367977}, {'label': 'positive', 'score': 0.979563295841217}]
# [{'label': 'negative', 'score': 0.015321332961320877}, {'label': 'neutral', 'score': 0.31802305579185486}, {'label': 'positive', 'score': 0.6666556596755981}]
# [{'label': 'negative', 'score': 0.012174660339951515}, {'label': 'neutral', 'score': 0.15160883963108063}, {'label': 'positive', 'score': 0.8362165093421936}]
# [{'label': 'negative', 'score': 0.3519521951675415}, {'label': 'neutral', 'score': 0.5255969166755676}, {'label': 'positive', 'score': 0.12245086580514908}]
# [{'label': 'negative', 'score': 0.19182591140270233}, {'label': 'neutral', 'score': 0.7394201755523682}, {'label': 'positive', 'score': 0.06875383853912354}]
# [{'label': 'negative', 'score': 0.0046936157159507275}, {'label': 'neutral', 'score': 0.16575714945793152}, {'label': 'positive', 'score': 0.829549252986908}]
# [{'label': 'negative', 'score': 0.0036351645831018686}, {'label': 'neutral', 'score': 0.02665741927921772}, {'label': 'positive', 'score': 0.9697073698043823}]
# [{'label': 'negative', 'score': 0.9442219138145447}, {'label': 'neutral', 'score': 0.050090305507183075}, {'label': 'positive', 'score': 0.0056877839379012585}]
# [{'label': 'negative', 'score': 0.5923540592193604}, {'label': 'neutral', 'score': 0.3802511692047119}, {'label': 'positive', 'score': 0.027394840493798256}]
# [{'label': 'negative', 'score': 0.8890181183815002}, {'label': 'neutral', 'score': 0.09581070393323898}, {'label': 'positive', 'score': 0.015171142295002937}]
# [{'label': 'negative', 'score': 0.27797237038612366}, {'label': 'neutral', 'score': 0.6702706217765808}, {'label': 'positive', 'score': 0.05175699666142464}]
# [{'label': 'negative', 'score': 0.00461473036557436}, {'label': 'neutral', 'score': 0.03291373327374458}, {'label': 'positive', 'score': 0.9624714851379395}]
# [{'label': 'negative', 'score': 0.015317394398152828}, {'label': 'neutral', 'score': 0.19699008762836456}, {'label': 'positive', 'score': 0.7876925468444824}]
# [{'label': 'negative', 'score': 0.0032562140841037035}, {'label': 'neutral', 'score': 0.016208985820412636}, {'label': 'positive', 'score': 0.9805348515510559}]
# [{'label': 'negative', 'score': 0.005583309568464756}, {'label': 'neutral', 'score': 0.10532018542289734}, {'label': 'positive', 'score': 0.8890965580940247}]
# [{'label': 'negative', 'score': 0.01383011694997549}, {'label': 'neutral', 'score': 0.4200998544692993}, {'label': 'positive', 'score': 0.5660700798034668}]
# [{'label': 'negative', 'score': 0.02798163890838623}, {'label': 'neutral', 'score': 0.21580184996128082}, {'label': 'positive', 'score': 0.7562164664268494}]
#  14%|█▎        | 144/1066 [00:01<00:08, 106.77it/s]
# [{'label': 'negative', 'score': 0.01809043064713478}, {'label': 'neutral', 'score': 0.15041771531105042}, {'label': 'positive', 'score': 0.8314918875694275}]
# [{'label': 'negative', 'score': 0.018397631123661995}, {'label': 'neutral', 'score': 0.29615142941474915}, {'label': 'positive', 'score': 0.6854509711265564}]
# [{'label': 'negative', 'score': 0.10492675751447678}, {'label': 'neutral', 'score': 0.6448068022727966}, {'label': 'positive', 'score': 0.250266432762146}]
# [{'label': 'negative', 'score': 0.011307370848953724}, {'label': 'neutral', 'score': 0.2559613883495331}, {'label': 'positive', 'score': 0.732731282711029}]
# [{'label': 'negative', 'score': 0.5925799608230591}, {'label': 'neutral', 'score': 0.33660444617271423}, {'label': 'positive', 'score': 0.07081557810306549}]
# [{'label': 'negative', 'score': 0.010373483411967754}, {'label': 'neutral', 'score': 0.23403853178024292}, {'label': 'positive', 'score': 0.7555879950523376}]
# [{'label': 'negative', 'score': 0.0025068242102861404}, {'label': 'neutral', 'score': 0.009680230170488358}, {'label': 'positive', 'score': 0.9878129363059998}]
# [{'label': 'negative', 'score': 0.04169631004333496}, {'label': 'neutral', 'score': 0.20108851790428162}, {'label': 'positive', 'score': 0.757215142250061}]
# [{'label': 'negative', 'score': 0.01191752590239048}, {'label': 'neutral', 'score': 0.1839814931154251}, {'label': 'positive', 'score': 0.8041009902954102}]
# [{'label': 'negative', 'score': 0.4222445487976074}, {'label': 'neutral', 'score': 0.456279993057251}, {'label': 'positive', 'score': 0.1214754581451416}]
# [{'label': 'negative', 'score': 0.4291501045227051}, {'label': 'neutral', 'score': 0.4512558877468109}, {'label': 'positive', 'score': 0.11959395557641983}]
# [{'label': 'negative', 'score': 0.024797186255455017}, {'label': 'neutral', 'score': 0.8259168863296509}, {'label': 'positive', 'score': 0.1492859125137329}]
# [{'label': 'negative', 'score': 0.020742366090416908}, {'label': 'neutral', 'score': 0.5631704330444336}, {'label': 'positive', 'score': 0.41608726978302}]
# [{'label': 'negative', 'score': 0.044042911380529404}, {'label': 'neutral', 'score': 0.3818470537662506}, {'label': 'positive', 'score': 0.5741100311279297}]
# [{'label': 'negative', 'score': 0.010792135260999203}, {'label': 'neutral', 'score': 0.11749317497015}, {'label': 'positive', 'score': 0.8717146515846252}]
# [{'label': 'negative', 'score': 0.2121729999780655}, {'label': 'neutral', 'score': 0.625764012336731}, {'label': 'positive', 'score': 0.16206301748752594}]
# [{'label': 'negative', 'score': 0.008681557141244411}, {'label': 'neutral', 'score': 0.2107255756855011}, {'label': 'positive', 'score': 0.7805927991867065}]
# [{'label': 'negative', 'score': 0.015180451795458794}, {'label': 'neutral', 'score': 0.09097331017255783}, {'label': 'positive', 'score': 0.8938462734222412}]
# [{'label': 'negative', 'score': 0.004555705469101667}, {'label': 'neutral', 'score': 0.032583896070718765}, {'label': 'positive', 'score': 0.9628603458404541}]
# [{'label': 'negative', 'score': 0.1248084083199501}, {'label': 'neutral', 'score': 0.5606802701950073}, {'label': 'positive', 'score': 0.3145112991333008}]
# [{'label': 'negative', 'score': 0.0056866551749408245}, {'label': 'neutral', 'score': 0.0709637925028801}, {'label': 'positive', 'score': 0.9233496189117432}]
# [{'label': 'negative', 'score': 0.010732128284871578}, {'label': 'neutral', 'score': 0.044613052159547806}, {'label': 'positive', 'score': 0.9446547627449036}]
# [{'label': 'negative', 'score': 0.009537426754832268}, {'label': 'neutral', 'score': 0.16606613993644714}, {'label': 'positive', 'score': 0.8243964314460754}]
#  16%|█▌        | 166/1066 [00:01<00:08, 106.85it/s]
# [{'label': 'negative', 'score': 0.36667490005493164}, {'label': 'neutral', 'score': 0.5234436392784119}, {'label': 'positive', 'score': 0.1098814532160759}]
# [{'label': 'negative', 'score': 0.01526102889329195}, {'label': 'neutral', 'score': 0.8258713483810425}, {'label': 'positive', 'score': 0.15886756777763367}]
# [{'label': 'negative', 'score': 0.6312147378921509}, {'label': 'neutral', 'score': 0.3082289397716522}, {'label': 'positive', 'score': 0.06055630370974541}]
# [{'label': 'negative', 'score': 0.002188293728977442}, {'label': 'neutral', 'score': 0.009893055073916912}, {'label': 'positive', 'score': 0.9879186749458313}]
# [{'label': 'negative', 'score': 0.25968316197395325}, {'label': 'neutral', 'score': 0.5958535075187683}, {'label': 'positive', 'score': 0.14446337521076202}]
# [{'label': 'negative', 'score': 0.004380576312541962}, {'label': 'neutral', 'score': 0.3381185829639435}, {'label': 'positive', 'score': 0.6575008034706116}]
# [{'label': 'negative', 'score': 0.00439627468585968}, {'label': 'neutral', 'score': 0.01671166531741619}, {'label': 'positive', 'score': 0.9788920879364014}]
# [{'label': 'negative', 'score': 0.0038793652784079313}, {'label': 'neutral', 'score': 0.04756707698106766}, {'label': 'positive', 'score': 0.9485535025596619}]
# [{'label': 'negative', 'score': 0.006630310323089361}, {'label': 'neutral', 'score': 0.06300956755876541}, {'label': 'positive', 'score': 0.9303601384162903}]
# [{'label': 'negative', 'score': 0.5953200459480286}, {'label': 'neutral', 'score': 0.38787543773651123}, {'label': 'positive', 'score': 0.016804572194814682}]
# [{'label': 'negative', 'score': 0.0054746828973293304}, {'label': 'neutral', 'score': 0.09683717787265778}, {'label': 'positive', 'score': 0.8976882100105286}]
# [{'label': 'negative', 'score': 0.21825985610485077}, {'label': 'neutral', 'score': 0.6047546863555908}, {'label': 'positive', 'score': 0.1769854724407196}]
# [{'label': 'negative', 'score': 0.2497836798429489}, {'label': 'neutral', 'score': 0.6830699443817139}, {'label': 'positive', 'score': 0.06714636832475662}]
# [{'label': 'negative', 'score': 0.011261212639510632}, {'label': 'neutral', 'score': 0.08044943958520889}, {'label': 'positive', 'score': 0.90828937292099}]
# [{'label': 'negative', 'score': 0.023959346115589142}, {'label': 'neutral', 'score': 0.6721143126487732}, {'label': 'positive', 'score': 0.30392634868621826}]
# [{'label': 'negative', 'score': 0.007257650140672922}, {'label': 'neutral', 'score': 0.15973705053329468}, {'label': 'positive', 'score': 0.8330052495002747}]
# [{'label': 'negative', 'score': 0.034719642251729965}, {'label': 'neutral', 'score': 0.34764447808265686}, {'label': 'positive', 'score': 0.6176358461380005}]
# [{'label': 'negative', 'score': 0.016511110588908195}, {'label': 'neutral', 'score': 0.2670448422431946}, {'label': 'positive', 'score': 0.7164440155029297}]
# [{'label': 'negative', 'score': 0.00931432843208313}, {'label': 'neutral', 'score': 0.17361582815647125}, {'label': 'positive', 'score': 0.8170698881149292}]
# [{'label': 'negative', 'score': 0.6492071747779846}, {'label': 'neutral', 'score': 0.328743577003479}, {'label': 'positive', 'score': 0.022049248218536377}]
# [{'label': 'negative', 'score': 0.020778333768248558}, {'label': 'neutral', 'score': 0.30909624695777893}, {'label': 'positive', 'score': 0.670125424861908}]
# [{'label': 'negative', 'score': 0.020217958837747574}, {'label': 'neutral', 'score': 0.32021239399909973}, {'label': 'positive', 'score': 0.6595696806907654}]
#  18%|█▊        | 188/1066 [00:01<00:08, 105.40it/s]
# [{'label': 'negative', 'score': 0.038150470703840256}, {'label': 'neutral', 'score': 0.6357796788215637}, {'label': 'positive', 'score': 0.3260698914527893}]
# [{'label': 'negative', 'score': 0.003443425055593252}, {'label': 'neutral', 'score': 0.032084133476018906}, {'label': 'positive', 'score': 0.9644724130630493}]
# [{'label': 'negative', 'score': 0.09083782136440277}, {'label': 'neutral', 'score': 0.8002095818519592}, {'label': 'positive', 'score': 0.10895262658596039}]
# [{'label': 'negative', 'score': 0.008591599762439728}, {'label': 'neutral', 'score': 0.35773587226867676}, {'label': 'positive', 'score': 0.6336725354194641}]
# [{'label': 'negative', 'score': 0.003365415381267667}, {'label': 'neutral', 'score': 0.04969921335577965}, {'label': 'positive', 'score': 0.9469354152679443}]
# [{'label': 'negative', 'score': 0.5233503580093384}, {'label': 'neutral', 'score': 0.4344850480556488}, {'label': 'positive', 'score': 0.042164500802755356}]
# [{'label': 'negative', 'score': 0.022102531045675278}, {'label': 'neutral', 'score': 0.645305871963501}, {'label': 'positive', 'score': 0.33259162306785583}]
# [{'label': 'negative', 'score': 0.002645733067765832}, {'label': 'neutral', 'score': 0.03487992286682129}, {'label': 'positive', 'score': 0.9624743461608887}]
# [{'label': 'negative', 'score': 0.14986982941627502}, {'label': 'neutral', 'score': 0.7854985594749451}, {'label': 'positive', 'score': 0.0646316409111023}]
# [{'label': 'negative', 'score': 0.025660919025540352}, {'label': 'neutral', 'score': 0.22117121517658234}, {'label': 'positive', 'score': 0.7531679272651672}]
# [{'label': 'negative', 'score': 0.005689749028533697}, {'label': 'neutral', 'score': 0.027708450332283974}, {'label': 'positive', 'score': 0.9666017889976501}]
# [{'label': 'negative', 'score': 0.012433602474629879}, {'label': 'neutral', 'score': 0.38242655992507935}, {'label': 'positive', 'score': 0.6051398515701294}]
# [{'label': 'negative', 'score': 0.03781099617481232}, {'label': 'neutral', 'score': 0.7371112108230591}, {'label': 'positive', 'score': 0.22507773339748383}]
# [{'label': 'negative', 'score': 0.04279961436986923}, {'label': 'neutral', 'score': 0.2935318648815155}, {'label': 'positive', 'score': 0.6636685132980347}]
# [{'label': 'negative', 'score': 0.30815979838371277}, {'label': 'neutral', 'score': 0.41736871004104614}, {'label': 'positive', 'score': 0.2744715213775635}]
# [{'label': 'negative', 'score': 0.030437802895903587}, {'label': 'neutral', 'score': 0.6996713280677795}, {'label': 'positive', 'score': 0.26989081501960754}]
# [{'label': 'negative', 'score': 0.7804859280586243}, {'label': 'neutral', 'score': 0.19558380544185638}, {'label': 'positive', 'score': 0.023930322378873825}]
# [{'label': 'negative', 'score': 0.029323754832148552}, {'label': 'neutral', 'score': 0.4293290078639984}, {'label': 'positive', 'score': 0.5413472652435303}]
# [{'label': 'negative', 'score': 0.02793566882610321}, {'label': 'neutral', 'score': 0.2788229286670685}, {'label': 'positive', 'score': 0.6932414174079895}]
# [{'label': 'negative', 'score': 0.003693860722705722}, {'label': 'neutral', 'score': 0.10416879504919052}, {'label': 'positive', 'score': 0.892137348651886}]
# [{'label': 'negative', 'score': 0.004766081925481558}, {'label': 'neutral', 'score': 0.057040490210056305}, {'label': 'positive', 'score': 0.9381934404373169}]
#  20%|█▉        | 210/1066 [00:02<00:08, 104.48it/s]
# [{'label': 'negative', 'score': 0.004919934086501598}, {'label': 'neutral', 'score': 0.0917547345161438}, {'label': 'positive', 'score': 0.9033253192901611}]
# [{'label': 'negative', 'score': 0.29403260350227356}, {'label': 'neutral', 'score': 0.5480082035064697}, {'label': 'positive', 'score': 0.1579591929912567}]
# [{'label': 'negative', 'score': 0.04165680333971977}, {'label': 'neutral', 'score': 0.3799320459365845}, {'label': 'positive', 'score': 0.5784111618995667}]
# [{'label': 'negative', 'score': 0.0021061499137431383}, {'label': 'neutral', 'score': 0.015530087053775787}, {'label': 'positive', 'score': 0.9823638200759888}]
# [{'label': 'negative', 'score': 0.019480692222714424}, {'label': 'neutral', 'score': 0.25675371289253235}, {'label': 'positive', 'score': 0.7237655520439148}]
# [{'label': 'negative', 'score': 0.01650872267782688}, {'label': 'neutral', 'score': 0.1283545345067978}, {'label': 'positive', 'score': 0.8551366925239563}]
# [{'label': 'negative', 'score': 0.8037555813789368}, {'label': 'neutral', 'score': 0.1876981407403946}, {'label': 'positive', 'score': 0.008546351455152035}]
# [{'label': 'negative', 'score': 0.004138997755944729}, {'label': 'neutral', 'score': 0.0959496721625328}, {'label': 'positive', 'score': 0.8999113440513611}]
# [{'label': 'negative', 'score': 0.342771053314209}, {'label': 'neutral', 'score': 0.6030383110046387}, {'label': 'positive', 'score': 0.05419057980179787}]
# [{'label': 'negative', 'score': 0.45921170711517334}, {'label': 'neutral', 'score': 0.5206026434898376}, {'label': 'positive', 'score': 0.020185694098472595}]
# [{'label': 'negative', 'score': 0.5421645045280457}, {'label': 'neutral', 'score': 0.4369739294052124}, {'label': 'positive', 'score': 0.020861567929387093}]
# [{'label': 'negative', 'score': 0.01097490917891264}, {'label': 'neutral', 'score': 0.17246617376804352}, {'label': 'positive', 'score': 0.8165589570999146}]
# [{'label': 'negative', 'score': 0.007657948881387711}, {'label': 'neutral', 'score': 0.12372208386659622}, {'label': 'positive', 'score': 0.868619978427887}]
# [{'label': 'negative', 'score': 0.0031468116212636232}, {'label': 'neutral', 'score': 0.015533113852143288}, {'label': 'positive', 'score': 0.9813201427459717}]
# [{'label': 'negative', 'score': 0.22619150578975677}, {'label': 'neutral', 'score': 0.6633853912353516}, {'label': 'positive', 'score': 0.1104230061173439}]
# [{'label': 'negative', 'score': 0.006107482127845287}, {'label': 'neutral', 'score': 0.05331481248140335}, {'label': 'positive', 'score': 0.9405776858329773}]
# [{'label': 'negative', 'score': 0.007412584964185953}, {'label': 'neutral', 'score': 0.08992548286914825}, {'label': 'positive', 'score': 0.902661919593811}]
# [{'label': 'negative', 'score': 0.009991845116019249}, {'label': 'neutral', 'score': 0.09083155542612076}, {'label': 'positive', 'score': 0.8991765975952148}]
# [{'label': 'negative', 'score': 0.1364155262708664}, {'label': 'neutral', 'score': 0.5743498206138611}, {'label': 'positive', 'score': 0.28923460841178894}]
# [{'label': 'negative', 'score': 0.009188062511384487}, {'label': 'neutral', 'score': 0.08093520253896713}, {'label': 'positive', 'score': 0.9098767638206482}]
# [{'label': 'negative', 'score': 0.006314809899777174}, {'label': 'neutral', 'score': 0.24485240876674652}, {'label': 'positive', 'score': 0.7488328218460083}]
# [{'label': 'negative', 'score': 0.22043900191783905}, {'label': 'neutral', 'score': 0.6574551463127136}, {'label': 'positive', 'score': 0.12210585176944733}]
#  22%|██▏       | 232/1066 [00:02<00:08, 100.85it/s]
# [{'label': 'negative', 'score': 0.0020178367849439383}, {'label': 'neutral', 'score': 0.01638142392039299}, {'label': 'positive', 'score': 0.9816007614135742}]
# [{'label': 'negative', 'score': 0.0069052488543093204}, {'label': 'neutral', 'score': 0.4288766086101532}, {'label': 'positive', 'score': 0.5642181634902954}]
# [{'label': 'negative', 'score': 0.8236886262893677}, {'label': 'neutral', 'score': 0.1663687527179718}, {'label': 'positive', 'score': 0.009942608885467052}]
# [{'label': 'negative', 'score': 0.1180327907204628}, {'label': 'neutral', 'score': 0.6413570046424866}, {'label': 'positive', 'score': 0.24061021208763123}]
# [{'label': 'negative', 'score': 0.007162043824791908}, {'label': 'neutral', 'score': 0.06089784950017929}, {'label': 'positive', 'score': 0.9319400787353516}]
# [{'label': 'negative', 'score': 0.6358984112739563}, {'label': 'neutral', 'score': 0.33604466915130615}, {'label': 'positive', 'score': 0.028056930750608444}]
# [{'label': 'negative', 'score': 0.138326033949852}, {'label': 'neutral', 'score': 0.7878756523132324}, {'label': 'positive', 'score': 0.07379834353923798}]
# [{'label': 'negative', 'score': 0.020215988159179688}, {'label': 'neutral', 'score': 0.3642401099205017}, {'label': 'positive', 'score': 0.6155439019203186}]
# [{'label': 'negative', 'score': 0.8446612358093262}, {'label': 'neutral', 'score': 0.12579312920570374}, {'label': 'positive', 'score': 0.02954559214413166}]
# [{'label': 'negative', 'score': 0.004421036224812269}, {'label': 'neutral', 'score': 0.11607864499092102}, {'label': 'positive', 'score': 0.8795003294944763}]
# [{'label': 'negative', 'score': 0.009936287067830563}, {'label': 'neutral', 'score': 0.5658071637153625}, {'label': 'positive', 'score': 0.4242565333843231}]
# [{'label': 'negative', 'score': 0.4319637715816498}, {'label': 'neutral', 'score': 0.3149156868457794}, {'label': 'positive', 'score': 0.2531205117702484}]
# [{'label': 'negative', 'score': 0.7737118601799011}, {'label': 'neutral', 'score': 0.2084221988916397}, {'label': 'positive', 'score': 0.017865922302007675}]
# [{'label': 'negative', 'score': 0.019776392728090286}, {'label': 'neutral', 'score': 0.23413221538066864}, {'label': 'positive', 'score': 0.7460914254188538}]
# [{'label': 'negative', 'score': 0.008487305603921413}, {'label': 'neutral', 'score': 0.1404915601015091}, {'label': 'positive', 'score': 0.8510211110115051}]
# [{'label': 'negative', 'score': 0.6055797934532166}, {'label': 'neutral', 'score': 0.3375435471534729}, {'label': 'positive', 'score': 0.05687671899795532}]
# [{'label': 'negative', 'score': 0.0027424634899944067}, {'label': 'neutral', 'score': 0.05353567376732826}, {'label': 'positive', 'score': 0.9437218904495239}]
# [{'label': 'negative', 'score': 0.6035827398300171}, {'label': 'neutral', 'score': 0.3121178150177002}, {'label': 'positive', 'score': 0.08429945260286331}]
# [{'label': 'negative', 'score': 0.007312547415494919}, {'label': 'neutral', 'score': 0.05141120031476021}, {'label': 'positive', 'score': 0.9412762522697449}]
# [{'label': 'negative', 'score': 0.011746039614081383}, {'label': 'neutral', 'score': 0.26703575253486633}, {'label': 'positive', 'score': 0.7212181687355042}]
#  24%|██▍       | 254/1066 [00:02<00:07, 103.09it/s]
# [{'label': 'negative', 'score': 0.05672817304730415}, {'label': 'neutral', 'score': 0.25783848762512207}, {'label': 'positive', 'score': 0.6854333281517029}]
# [{'label': 'negative', 'score': 0.010710963979363441}, {'label': 'neutral', 'score': 0.4698774218559265}, {'label': 'positive', 'score': 0.519411563873291}]
# [{'label': 'negative', 'score': 0.6540008187294006}, {'label': 'neutral', 'score': 0.32968875765800476}, {'label': 'positive', 'score': 0.01631046272814274}]
# [{'label': 'negative', 'score': 0.3974696695804596}, {'label': 'neutral', 'score': 0.5452924370765686}, {'label': 'positive', 'score': 0.057237934321165085}]
# [{'label': 'negative', 'score': 0.6117007732391357}, {'label': 'neutral', 'score': 0.3457655906677246}, {'label': 'positive', 'score': 0.04253366217017174}]
# [{'label': 'negative', 'score': 0.012687966227531433}, {'label': 'neutral', 'score': 0.7510493397712708}, {'label': 'positive', 'score': 0.2362627536058426}]
# [{'label': 'negative', 'score': 0.14690718054771423}, {'label': 'neutral', 'score': 0.5717218518257141}, {'label': 'positive', 'score': 0.2813710570335388}]
# [{'label': 'negative', 'score': 0.01634938269853592}, {'label': 'neutral', 'score': 0.12138771265745163}, {'label': 'positive', 'score': 0.8622629642486572}]
# [{'label': 'negative', 'score': 0.06716365367174149}, {'label': 'neutral', 'score': 0.6168507933616638}, {'label': 'positive', 'score': 0.3159855604171753}]
# [{'label': 'negative', 'score': 0.04126754030585289}, {'label': 'neutral', 'score': 0.8886216282844543}, {'label': 'positive', 'score': 0.07011085003614426}]
# [{'label': 'negative', 'score': 0.09201440960168839}, {'label': 'neutral', 'score': 0.6605001091957092}, {'label': 'positive', 'score': 0.24748541414737701}]
# [{'label': 'negative', 'score': 0.3922314941883087}, {'label': 'neutral', 'score': 0.535144031047821}, {'label': 'positive', 'score': 0.07262447476387024}]
# [{'label': 'negative', 'score': 0.002597193466499448}, {'label': 'neutral', 'score': 0.016512174159288406}, {'label': 'positive', 'score': 0.9808906316757202}]
# [{'label': 'negative', 'score': 0.005441606510430574}, {'label': 'neutral', 'score': 0.08771682530641556}, {'label': 'positive', 'score': 0.906841516494751}]
# [{'label': 'negative', 'score': 0.0067494404502213}, {'label': 'neutral', 'score': 0.037665966898202896}, {'label': 'positive', 'score': 0.9555845856666565}]
# [{'label': 'negative', 'score': 0.7149198055267334}, {'label': 'neutral', 'score': 0.25282490253448486}, {'label': 'positive', 'score': 0.032255299389362335}]
# [{'label': 'negative', 'score': 0.740323007106781}, {'label': 'neutral', 'score': 0.22019034624099731}, {'label': 'positive', 'score': 0.039486657828092575}]
# [{'label': 'negative', 'score': 0.05837947875261307}, {'label': 'neutral', 'score': 0.4013150930404663}, {'label': 'positive', 'score': 0.5403054356575012}]
# [{'label': 'negative', 'score': 0.45500072836875916}, {'label': 'neutral', 'score': 0.4845897853374481}, {'label': 'positive', 'score': 0.06040938198566437}]
# [{'label': 'negative', 'score': 0.41830331087112427}, {'label': 'neutral', 'score': 0.4886429011821747}, {'label': 'positive', 'score': 0.09305378794670105}]
# [{'label': 'negative', 'score': 0.008449983783066273}, {'label': 'neutral', 'score': 0.05344337224960327}, {'label': 'positive', 'score': 0.9381066560745239}]
# [{'label': 'negative', 'score': 0.014739178121089935}, {'label': 'neutral', 'score': 0.17573820054531097}, {'label': 'positive', 'score': 0.8095226287841797}]
#  25%|██▍       | 265/1066 [00:02<00:07, 104.04it/s]
# [{'label': 'negative', 'score': 0.011252349242568016}, {'label': 'neutral', 'score': 0.719847559928894}, {'label': 'positive', 'score': 0.268900066614151}]
# [{'label': 'negative', 'score': 0.6458753943443298}, {'label': 'neutral', 'score': 0.33612382411956787}, {'label': 'positive', 'score': 0.018000777810811996}]
# [{'label': 'negative', 'score': 0.0071744672022759914}, {'label': 'neutral', 'score': 0.8382632732391357}, {'label': 'positive', 'score': 0.15456226468086243}]
# [{'label': 'negative', 'score': 0.6093475818634033}, {'label': 'neutral', 'score': 0.3580082654953003}, {'label': 'positive', 'score': 0.0326441265642643}]
# [{'label': 'negative', 'score': 0.03647000342607498}, {'label': 'neutral', 'score': 0.1090942770242691}, {'label': 'positive', 'score': 0.8544356822967529}]
# [{'label': 'negative', 'score': 0.004130012355744839}, {'label': 'neutral', 'score': 0.06877424567937851}, {'label': 'positive', 'score': 0.9270957708358765}]
# [{'label': 'negative', 'score': 0.008386436849832535}, {'label': 'neutral', 'score': 0.0907846987247467}, {'label': 'positive', 'score': 0.9008288979530334}]
# [{'label': 'negative', 'score': 0.022627411410212517}, {'label': 'neutral', 'score': 0.28652146458625793}, {'label': 'positive', 'score': 0.6908511519432068}]
# [{'label': 'negative', 'score': 0.8106994032859802}, {'label': 'neutral', 'score': 0.171746626496315}, {'label': 'positive', 'score': 0.01755397766828537}]
# [{'label': 'negative', 'score': 0.007508717477321625}, {'label': 'neutral', 'score': 0.06594511866569519}, {'label': 'positive', 'score': 0.9265461564064026}]
# [{'label': 'negative', 'score': 0.06270011514425278}, {'label': 'neutral', 'score': 0.5290517210960388}, {'label': 'positive', 'score': 0.4082481861114502}]
# [{'label': 'negative', 'score': 0.006561925634741783}, {'label': 'neutral', 'score': 0.02190745808184147}, {'label': 'positive', 'score': 0.9715306162834167}]
# [{'label': 'negative', 'score': 0.3507561683654785}, {'label': 'neutral', 'score': 0.5938190221786499}, {'label': 'positive', 'score': 0.055424805730581284}]
# [{'label': 'negative', 'score': 0.0034117363393306732}, {'label': 'neutral', 'score': 0.06607022136449814}, {'label': 'positive', 'score': 0.9305180311203003}]
# [{'label': 'negative', 'score': 0.061668623238801956}, {'label': 'neutral', 'score': 0.6572079658508301}, {'label': 'positive', 'score': 0.2811233401298523}]
# [{'label': 'negative', 'score': 0.24484826624393463}, {'label': 'neutral', 'score': 0.6788898706436157}, {'label': 'positive', 'score': 0.07626188546419144}]
# [{'label': 'negative', 'score': 0.25955110788345337}, {'label': 'neutral', 'score': 0.6639862656593323}, {'label': 'positive', 'score': 0.07646256685256958}]
# [{'label': 'negative', 'score': 0.02143898792564869}, {'label': 'neutral', 'score': 0.3076290190219879}, {'label': 'positive', 'score': 0.6709319353103638}]
# [{'label': 'negative', 'score': 0.05136760696768761}, {'label': 'neutral', 'score': 0.7003618478775024}, {'label': 'positive', 'score': 0.24827055633068085}]
# [{'label': 'negative', 'score': 0.2282176911830902}, {'label': 'neutral', 'score': 0.4334336817264557}, {'label': 'positive', 'score': 0.3383485674858093}]
#  27%|██▋       | 286/1066 [00:02<00:08, 87.80it/s]
# [{'label': 'negative', 'score': 0.017373492941260338}, {'label': 'neutral', 'score': 0.23154020309448242}, {'label': 'positive', 'score': 0.7510862946510315}]
# [{'label': 'negative', 'score': 0.021427365019917488}, {'label': 'neutral', 'score': 0.23045490682125092}, {'label': 'positive', 'score': 0.7481176853179932}]
# [{'label': 'negative', 'score': 0.0037758012767881155}, {'label': 'neutral', 'score': 0.03283489868044853}, {'label': 'positive', 'score': 0.9633892774581909}]
# [{'label': 'negative', 'score': 0.27416205406188965}, {'label': 'neutral', 'score': 0.5766223073005676}, {'label': 'positive', 'score': 0.1492156833410263}]
# [{'label': 'negative', 'score': 0.5145049691200256}, {'label': 'neutral', 'score': 0.4153863191604614}, {'label': 'positive', 'score': 0.07010871171951294}]
# [{'label': 'negative', 'score': 0.27733030915260315}, {'label': 'neutral', 'score': 0.6756449341773987}, {'label': 'positive', 'score': 0.04702481999993324}]
# [{'label': 'negative', 'score': 0.7491950988769531}, {'label': 'neutral', 'score': 0.2260696440935135}, {'label': 'positive', 'score': 0.024735193699598312}]
# [{'label': 'negative', 'score': 0.017579952254891396}, {'label': 'neutral', 'score': 0.22045843303203583}, {'label': 'positive', 'score': 0.7619615793228149}]
# [{'label': 'negative', 'score': 0.15060898661613464}, {'label': 'neutral', 'score': 0.5713268518447876}, {'label': 'positive', 'score': 0.27806413173675537}]
# [{'label': 'negative', 'score': 0.12423659861087799}, {'label': 'neutral', 'score': 0.7228086590766907}, {'label': 'positive', 'score': 0.15295475721359253}]
# [{'label': 'negative', 'score': 0.842863142490387}, {'label': 'neutral', 'score': 0.15146692097187042}, {'label': 'positive', 'score': 0.005669945385307074}]
# [{'label': 'negative', 'score': 0.03184615448117256}, {'label': 'neutral', 'score': 0.8215730786323547}, {'label': 'positive', 'score': 0.14658072590827942}]
# [{'label': 'negative', 'score': 0.03709375113248825}, {'label': 'neutral', 'score': 0.2263796031475067}, {'label': 'positive', 'score': 0.736526608467102}]
# [{'label': 'negative', 'score': 0.8035751581192017}, {'label': 'neutral', 'score': 0.17401067912578583}, {'label': 'positive', 'score': 0.022414155304431915}]
# [{'label': 'negative', 'score': 0.0054159509018063545}, {'label': 'neutral', 'score': 0.016563408076763153}, {'label': 'positive', 'score': 0.9780206084251404}]
#  29%|██▊       | 304/1066 [00:03<00:09, 83.69it/s]
# [{'label': 'negative', 'score': 0.08345644176006317}, {'label': 'neutral', 'score': 0.6752660274505615}, {'label': 'positive', 'score': 0.24127750098705292}]
# [{'label': 'negative', 'score': 0.644315779209137}, {'label': 'neutral', 'score': 0.33920881152153015}, {'label': 'positive', 'score': 0.01647539995610714}]
# [{'label': 'negative', 'score': 0.17371027171611786}, {'label': 'neutral', 'score': 0.549693763256073}, {'label': 'positive', 'score': 0.2765960097312927}]
# [{'label': 'negative', 'score': 0.6687211990356445}, {'label': 'neutral', 'score': 0.31873512268066406}, {'label': 'positive', 'score': 0.01254370715469122}]
# [{'label': 'negative', 'score': 0.0067926570773124695}, {'label': 'neutral', 'score': 0.03758933022618294}, {'label': 'positive', 'score': 0.9556180238723755}]
# [{'label': 'negative', 'score': 0.5169731378555298}, {'label': 'neutral', 'score': 0.4190169870853424}, {'label': 'positive', 'score': 0.06400986015796661}]
# [{'label': 'negative', 'score': 0.002466231817379594}, {'label': 'neutral', 'score': 0.009718285873532295}, {'label': 'positive', 'score': 0.9878154993057251}]
# [{'label': 'negative', 'score': 0.5492838025093079}, {'label': 'neutral', 'score': 0.34125879406929016}, {'label': 'positive', 'score': 0.10945741832256317}]
# ...
# [{'label': 'negative', 'score': 0.8238517045974731}, {'label': 'neutral', 'score': 0.16819553077220917}, {'label': 'positive', 'score': 0.007952685467898846}]
# [{'label': 'negative', 'score': 0.824595034122467}, {'label': 'neutral', 'score': 0.16806234419345856}, {'label': 'positive', 'score': 0.007342546712607145}]
# [{'label': 'negative', 'score': 0.8964770436286926}, {'label': 'neutral', 'score': 0.09693262726068497}, {'label': 'positive', 'score': 0.00659031281247735}]
# [{'label': 'negative', 'score': 0.5142036080360413}, {'label': 'neutral', 'score': 0.4415053725242615}, {'label': 'positive', 'score': 0.044290974736213684}]
# [{'label': 'negative', 'score': 0.8503841161727905}, {'label': 'neutral', 'score': 0.12505407631397247}, {'label': 'positive', 'score': 0.024561790749430656}]
# [{'label': 'negative', 'score': 0.6139947175979614}, {'label': 'neutral', 'score': 0.36403006315231323}, {'label': 'positive', 'score': 0.021975204348564148}]
# [{'label': 'negative', 'score': 0.9222079515457153}, {'label': 'neutral', 'score': 0.06892354786396027}, {'label': 'positive', 'score': 0.008868549019098282}]
# [{'label': 'negative', 'score': 0.4613494873046875}, {'label': 'neutral', 'score': 0.46428337693214417}, {'label': 'positive', 'score': 0.07436716556549072}]
# [{'label': 'negative', 'score': 0.10312606394290924}, {'label': 'neutral', 'score': 0.7551906704902649}, {'label': 'positive', 'score': 0.14168325066566467}]
# [{'label': 'negative', 'score': 0.7797091007232666}, {'label': 'neutral', 'score': 0.2069721817970276}, {'label': 'positive', 'score': 0.013318701647222042}]
# [{'label': 'negative', 'score': 0.8369069695472717}, {'label': 'neutral', 'score': 0.15439443290233612}, {'label': 'positive', 'score': 0.00869862549006939}]
# [{'label': 'negative', 'score': 0.8966015577316284}, {'label': 'neutral', 'score': 0.09669145941734314}, {'label': 'positive', 'score': 0.0067069148644804955}]
# [{'label': 'negative', 'score': 0.28382408618927}, {'label': 'neutral', 'score': 0.5606268644332886}, {'label': 'positive', 'score': 0.1555490791797638}]
# [{'label': 'negative', 'score': 0.6144213676452637}, {'label': 'neutral', 'score': 0.3711394965648651}, {'label': 'positive', 'score': 0.014439137652516365}]
# [{'label': 'negative', 'score': 0.6091968417167664}, {'label': 'neutral', 'score': 0.3714934289455414}, {'label': 'positive', 'score': 0.0193097572773695}]
# [{'label': 'negative', 'score': 0.7179582715034485}, {'label': 'neutral', 'score': 0.26621147990226746}, {'label': 'positive', 'score': 0.015830202028155327}]
#  94%|█████████▍| 1004/1066 [00:10<00:00, 106.12it/s]
# [{'label': 'negative', 'score': 0.8159232139587402}, {'label': 'neutral', 'score': 0.173950657248497}, {'label': 'positive', 'score': 0.010126128792762756}]
# [{'label': 'negative', 'score': 0.6286802291870117}, {'label': 'neutral', 'score': 0.33867406845092773}, {'label': 'positive', 'score': 0.03264569863677025}]
# [{'label': 'negative', 'score': 0.8598794341087341}, {'label': 'neutral', 'score': 0.13050472736358643}, {'label': 'positive', 'score': 0.009615805931389332}]
# [{'label': 'negative', 'score': 0.9134005904197693}, {'label': 'neutral', 'score': 0.07734989374876022}, {'label': 'positive', 'score': 0.009249521419405937}]
# [{'label': 'negative', 'score': 0.4679095149040222}, {'label': 'neutral', 'score': 0.483191579580307}, {'label': 'positive', 'score': 0.048898980021476746}]
# [{'label': 'negative', 'score': 0.017824454233050346}, {'label': 'neutral', 'score': 0.19512046873569489}, {'label': 'positive', 'score': 0.7870550751686096}]
# [{'label': 'negative', 'score': 0.022801131010055542}, {'label': 'neutral', 'score': 0.22674065828323364}, {'label': 'positive', 'score': 0.7504581809043884}]
# [{'label': 'negative', 'score': 0.018833482638001442}, {'label': 'neutral', 'score': 0.19441476464271545}, {'label': 'positive', 'score': 0.7867518067359924}]
# [{'label': 'negative', 'score': 0.950040340423584}, {'label': 'neutral', 'score': 0.044152241200208664}, {'label': 'positive', 'score': 0.005807443521916866}]
# [{'label': 'negative', 'score': 0.48021477460861206}, {'label': 'neutral', 'score': 0.4436308443546295}, {'label': 'positive', 'score': 0.07615438848733902}]
# [{'label': 'negative', 'score': 0.6126587390899658}, {'label': 'neutral', 'score': 0.330066055059433}, {'label': 'positive', 'score': 0.05727523937821388}]
# [{'label': 'negative', 'score': 0.8425449728965759}, {'label': 'neutral', 'score': 0.14231479167938232}, {'label': 'positive', 'score': 0.015140215866267681}]
# [{'label': 'negative', 'score': 0.08825279772281647}, {'label': 'neutral', 'score': 0.8625995516777039}, {'label': 'positive', 'score': 0.04914763197302818}]
# [{'label': 'negative', 'score': 0.06831470131874084}, {'label': 'neutral', 'score': 0.7085530757904053}, {'label': 'positive', 'score': 0.22313228249549866}]
# [{'label': 'negative', 'score': 0.14553311467170715}, {'label': 'neutral', 'score': 0.48229071497917175}, {'label': 'positive', 'score': 0.3721761703491211}]
# [{'label': 'negative', 'score': 0.20577111840248108}, {'label': 'neutral', 'score': 0.479302316904068}, {'label': 'positive', 'score': 0.3149265944957733}]
# [{'label': 'negative', 'score': 0.9509932994842529}, {'label': 'neutral', 'score': 0.044022150337696075}, {'label': 'positive', 'score': 0.00498456135392189}]
# [{'label': 'negative', 'score': 0.21134473383426666}, {'label': 'neutral', 'score': 0.6590262651443481}, {'label': 'positive', 'score': 0.1296290010213852}]
# [{'label': 'negative', 'score': 0.8323310017585754}, {'label': 'neutral', 'score': 0.15459267795085907}, {'label': 'positive', 'score': 0.013076309114694595}]
# [{'label': 'negative', 'score': 0.7672150135040283}, {'label': 'neutral', 'score': 0.22272531688213348}, {'label': 'positive', 'score': 0.010059569031000137}]
# [{'label': 'negative', 'score': 0.913915753364563}, {'label': 'neutral', 'score': 0.07926177233457565}, {'label': 'positive', 'score': 0.006822486873716116}]
# [{'label': 'negative', 'score': 0.4860873222351074}, {'label': 'neutral', 'score': 0.48319000005722046}, {'label': 'positive', 'score': 0.030722705647349358}]
# [{'label': 'negative', 'score': 0.23125092685222626}, {'label': 'neutral', 'score': 0.6464129090309143}, {'label': 'positive', 'score': 0.12233611196279526}]
#  96%|█████████▌| 1026/1066 [00:10<00:00, 102.03it/s]
# [{'label': 'negative', 'score': 0.45362967252731323}, {'label': 'neutral', 'score': 0.42137643694877625}, {'label': 'positive', 'score': 0.12499386072158813}]
# [{'label': 'negative', 'score': 0.6497556567192078}, {'label': 'neutral', 'score': 0.322793185710907}, {'label': 'positive', 'score': 0.02745119296014309}]
# [{'label': 'negative', 'score': 0.3767475187778473}, {'label': 'neutral', 'score': 0.5621631741523743}, {'label': 'positive', 'score': 0.061089325696229935}]
# [{'label': 'negative', 'score': 0.13970988988876343}, {'label': 'neutral', 'score': 0.6938965916633606}, {'label': 'positive', 'score': 0.16639354825019836}]
# [{'label': 'negative', 'score': 0.3899001181125641}, {'label': 'neutral', 'score': 0.5847851037979126}, {'label': 'positive', 'score': 0.025314705446362495}]
# [{'label': 'negative', 'score': 0.8156619668006897}, {'label': 'neutral', 'score': 0.17295660078525543}, {'label': 'positive', 'score': 0.011381424032151699}]
# [{'label': 'negative', 'score': 0.3752805292606354}, {'label': 'neutral', 'score': 0.5017001628875732}, {'label': 'positive', 'score': 0.12301931530237198}]
# [{'label': 'negative', 'score': 0.7012448310852051}, {'label': 'neutral', 'score': 0.2783333957195282}, {'label': 'positive', 'score': 0.020421775057911873}]
# [{'label': 'negative', 'score': 0.017752142623066902}, {'label': 'neutral', 'score': 0.30657291412353516}, {'label': 'positive', 'score': 0.6756749749183655}]
# [{'label': 'negative', 'score': 0.9032792448997498}, {'label': 'neutral', 'score': 0.09067384898662567}, {'label': 'positive', 'score': 0.006046917289495468}]
# [{'label': 'negative', 'score': 0.48156023025512695}, {'label': 'neutral', 'score': 0.476497620344162}, {'label': 'positive', 'score': 0.041942160576581955}]
# [{'label': 'negative', 'score': 0.9005281329154968}, {'label': 'neutral', 'score': 0.09304460138082504}, {'label': 'positive', 'score': 0.006427246145904064}]
# [{'label': 'negative', 'score': 0.9295085072517395}, {'label': 'neutral', 'score': 0.06451379507780075}, {'label': 'positive', 'score': 0.005977618508040905}]
# [{'label': 'negative', 'score': 0.16645017266273499}, {'label': 'neutral', 'score': 0.5294603109359741}, {'label': 'positive', 'score': 0.3040895164012909}]
# [{'label': 'negative', 'score': 0.7521685361862183}, {'label': 'neutral', 'score': 0.23274533450603485}, {'label': 'positive', 'score': 0.015086152590811253}]
# [{'label': 'negative', 'score': 0.7162044048309326}, {'label': 'neutral', 'score': 0.27262642979621887}, {'label': 'positive', 'score': 0.011169152334332466}]
# [{'label': 'negative', 'score': 0.8959540128707886}, {'label': 'neutral', 'score': 0.09935645759105682}, {'label': 'positive', 'score': 0.0046895635314285755}]
# [{'label': 'negative', 'score': 0.8245965838432312}, {'label': 'neutral', 'score': 0.16258962452411652}, {'label': 'positive', 'score': 0.012813722714781761}]
# [{'label': 'negative', 'score': 0.6148387789726257}, {'label': 'neutral', 'score': 0.36524710059165955}, {'label': 'positive', 'score': 0.019914088770747185}]
# [{'label': 'negative', 'score': 0.5884483456611633}, {'label': 'neutral', 'score': 0.3843242824077606}, {'label': 'positive', 'score': 0.027227390557527542}]
#  98%|█████████▊| 1048/1066 [00:10<00:00, 104.93it/s]
# [{'label': 'negative', 'score': 0.06191995367407799}, {'label': 'neutral', 'score': 0.811259388923645}, {'label': 'positive', 'score': 0.12682068347930908}]
# [{'label': 'negative', 'score': 0.8747042417526245}, {'label': 'neutral', 'score': 0.11452040821313858}, {'label': 'positive', 'score': 0.010775321163237095}]
# [{'label': 'negative', 'score': 0.1831476241350174}, {'label': 'neutral', 'score': 0.7090993523597717}, {'label': 'positive', 'score': 0.10775294154882431}]
# [{'label': 'negative', 'score': 0.737317681312561}, {'label': 'neutral', 'score': 0.2470230758190155}, {'label': 'positive', 'score': 0.01565922424197197}]
# [{'label': 'negative', 'score': 0.8234103322029114}, {'label': 'neutral', 'score': 0.161861389875412}, {'label': 'positive', 'score': 0.01472825650125742}]
# [{'label': 'negative', 'score': 0.7951980829238892}, {'label': 'neutral', 'score': 0.16795268654823303}, {'label': 'positive', 'score': 0.036849312484264374}]
# [{'label': 'negative', 'score': 0.6539247632026672}, {'label': 'neutral', 'score': 0.32733023166656494}, {'label': 'positive', 'score': 0.018745066598057747}]
# [{'label': 'negative', 'score': 0.712311327457428}, {'label': 'neutral', 'score': 0.2677837014198303}, {'label': 'positive', 'score': 0.019904961809515953}]
# [{'label': 'negative', 'score': 0.7830403447151184}, {'label': 'neutral', 'score': 0.18549717962741852}, {'label': 'positive', 'score': 0.03146248310804367}]
# [{'label': 'negative', 'score': 0.7418417930603027}, {'label': 'neutral', 'score': 0.2453158050775528}, {'label': 'positive', 'score': 0.01284242607653141}]
# [{'label': 'negative', 'score': 0.9011727571487427}, {'label': 'neutral', 'score': 0.0917152389883995}, {'label': 'positive', 'score': 0.0071119642816483974}]
# [{'label': 'negative', 'score': 0.6103655099868774}, {'label': 'neutral', 'score': 0.3110722601413727}, {'label': 'positive', 'score': 0.07856222242116928}]
# [{'label': 'negative', 'score': 0.6347007751464844}, {'label': 'neutral', 'score': 0.33603435754776}, {'label': 'positive', 'score': 0.02926487848162651}]
# [{'label': 'negative', 'score': 0.06050798296928406}, {'label': 'neutral', 'score': 0.4957664906978607}, {'label': 'positive', 'score': 0.44372549653053284}]
# [{'label': 'negative', 'score': 0.9246385097503662}, {'label': 'neutral', 'score': 0.07042393088340759}, {'label': 'positive', 'score': 0.004937501158565283}]
# [{'label': 'negative', 'score': 0.07471813261508942}, {'label': 'neutral', 'score': 0.8327409029006958}, {'label': 'positive', 'score': 0.09254103899002075}]
# [{'label': 'negative', 'score': 0.7546690106391907}, {'label': 'neutral', 'score': 0.23063325881958008}, {'label': 'positive', 'score': 0.01469773706048727}]
# [{'label': 'negative', 'score': 0.6227675676345825}, {'label': 'neutral', 'score': 0.33562177419662476}, {'label': 'positive', 'score': 0.04161067679524422}]
# [{'label': 'negative', 'score': 0.8512213826179504}, {'label': 'neutral', 'score': 0.13814274966716766}, {'label': 'positive', 'score': 0.010635803453624249}]
# [{'label': 'negative', 'score': 0.7731993198394775}, {'label': 'neutral', 'score': 0.2100633680820465}, {'label': 'positive', 'score': 0.016737306490540504}]
# [{'label': 'negative', 'score': 0.8989673852920532}, {'label': 'neutral', 'score': 0.09636138379573822}, {'label': 'positive', 'score': 0.004671176895499229}]
# [{'label': 'negative', 'score': 0.3690614104270935}, {'label': 'neutral', 'score': 0.6110514402389526}, {'label': 'positive', 'score': 0.019887113943696022}]
# 100%|██████████| 1066/1066 [00:11<00:00, 96.60it/s]
# [{'label': 'negative', 'score': 0.8047021627426147}, {'label': 'neutral', 'score': 0.1857047975063324}, {'label': 'positive', 'score': 0.009593049995601177}]
# [{'label': 'negative', 'score': 0.4256116449832916}, {'label': 'neutral', 'score': 0.5033800601959229}, {'label': 'positive', 'score': 0.07100826501846313}]
# [{'label': 'negative', 'score': 0.6854838132858276}, {'label': 'neutral', 'score': 0.2901689410209656}, {'label': 'positive', 'score': 0.0243473332375288}]
# [{'label': 'negative', 'score': 0.8082235455513}, {'label': 'neutral', 'score': 0.1835911124944687}, {'label': 'positive', 'score': 0.008185304701328278}]
# [{'label': 'negative', 'score': 0.13469646871089935}, {'label': 'neutral', 'score': 0.4916398525238037}, {'label': 'positive', 'score': 0.37366366386413574}]
# [{'label': 'negative', 'score': 0.9165812134742737}, {'label': 'neutral', 'score': 0.07223007827997208}, {'label': 'positive', 'score': 0.011188686825335026}]
# [{'label': 'negative', 'score': 0.6963605284690857}, {'label': 'neutral', 'score': 0.2840748131275177}, {'label': 'positive', 'score': 0.019564669579267502}]
# [{'label': 'negative', 'score': 0.9171780943870544}, {'label': 'neutral', 'score': 0.0755658745765686}, {'label': 'positive', 'score': 0.007256014738231897}]
# [{'label': 'negative', 'score': 0.4067014753818512}, {'label': 'neutral', 'score': 0.473389208316803}, {'label': 'positive', 'score': 0.1199093908071518}]
# [{'label': 'negative', 'score': 0.78398197889328}, {'label': 'neutral', 'score': 0.20309977233409882}, {'label': 'positive', 'score': 0.012918202206492424}]
# [{'label': 'negative', 'score': 0.42400065064430237}, {'label': 'neutral', 'score': 0.5450747013092041}, {'label': 'positive', 'score': 0.030924612656235695}]
# [{'label': 'negative', 'score': 0.5456550121307373}, {'label': 'neutral', 'score': 0.43565860390663147}, {'label': 'positive', 'score': 0.018686436116695404}]
# [{'label': 'negative', 'score': 0.8698654770851135}, {'label': 'neutral', 'score': 0.1177823543548584}, {'label': 'positive', 'score': 0.012352179735898972}]
# [{'label': 'negative', 'score': 0.9316494464874268}, {'label': 'neutral', 'score': 0.0618242472410202}, {'label': 'positive', 'score': 0.0065262820571660995}]
# [{'label': 'negative', 'score': 0.27830660343170166}, {'label': 'neutral', 'score': 0.5542842149734497}, {'label': 'positive', 'score': 0.16740912199020386}]
# [{'label': 'negative', 'score': 0.7510579228401184}, {'label': 'neutral', 'score': 0.23910640180110931}, {'label': 'positive', 'score': 0.009835612960159779}]
# [{'label': 'negative', 'score': 0.4133340120315552}, {'label': 'neutral', 'score': 0.5482679605484009}, {'label': 'positive', 'score': 0.038397978991270065}]
# [{'label': 'negative', 'score': 0.8362504243850708}, {'label': 'neutral', 'score': 0.150909885764122}, {'label': 'positive', 'score': 0.012839589267969131}]

# %%
from sklearn.metrics import classification_report

def evaluate_performance(y_true,y_pred):
  performance = classification_report(
      y_true, y_pred,
      target_names = ["Negative Review","Positive Review"]
  )
  print(performance)

# %%
evaluate_performance(data["test"]["label"],y_pred)
# Out:
#                  precision    recall  f1-score   support
#
# Negative Review       0.76      0.88      0.81       533
# Positive Review       0.86      0.72      0.78       533
#
#        accuracy                           0.80      1066
#       macro avg       0.81      0.80      0.80      1066
#    weighted avg       0.81      0.80      0.80      1066

# %%
from sentence_transformers import SentenceTransformer

# 모델을 로드합니다.
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

# 텍스트를 임베딩으로 변환합니다.
train_embeddings = model.encode(list(data["train"]["text"]), show_progress_bar=True)
test_embeddings = model.encode(list(data["test"]["text"]), show_progress_bar=True)
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--sentence-transformers--all-mpnet-base-v2/snapshots/12e86a3c702fc3c50205a8db88f0ec7c0b6b94a0/config.json
# Model config MPNetConfig {
#   "architectures": [
#     "MPNetForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "mpnet",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "relative_attention_num_buckets": 32,
#   "transformers_version": "4.53.2",
#   "vocab_size": 30527
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--sentence-transformers--all-mpnet-base-v2/snapshots/12e86a3c702fc3c50205a8db88f0ec7c0b6b94a0/model.safetensors
# All model checkpoint weights were used when initializing MPNetModel.
#
# All the weights of MPNetModel were initialized from the model checkpoint at sentence-transformers/all-mpnet-base-v2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use MPNetModel for predictions without further training.
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--sentence-transformers--all-mpnet-base-v2/snapshots/12e86a3c702fc3c50205a8db88f0ec7c0b6b94a0/vocab.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--sentence-transformers--all-mpnet-base-v2/snapshots/12e86a3c702fc3c50205a8db88f0ec7c0b6b94a0/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--sentence-transformers--all-mpnet-base-v2/snapshots/12e86a3c702fc3c50205a8db88f0ec7c0b6b94a0/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--sentence-transformers--all-mpnet-base-v2/snapshots/12e86a3c702fc3c50205a8db88f0ec7c0b6b94a0/tokenizer_config.json
# loading file chat_template.jinja from cache at None
# Batches:   0%|          | 0/267 [00:00<?, ?it/s]
# Batches:   0%|          | 0/34 [00:00<?, ?it/s]

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(random_state=42)
clf.fit(train_embeddings, data["train"]["label"])
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = clf.predict(test_embeddings)
evaluate_performance(data["test"]["label"],y_pred)
# Out:
#                  precision    recall  f1-score   support
#
# Negative Review       0.85      0.86      0.85       533
# Positive Review       0.86      0.85      0.85       533
#
#        accuracy                           0.85      1066
#       macro avg       0.85      0.85      0.85      1066
#    weighted avg       0.85      0.85      0.85      1066

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

# 타깃 레이블에 대한 문서의 임베딩을 모두 평균하여 타깃 임베딩을 만듭니다.
df = pd.DataFrame(np.hstack([train_embeddings, np.array(data["train"]["label"]).reshape(-1, 1)]))
averaged_target_embeddings = df.groupby(768).mean().values
sim_matrix = cosine_similarity(test_embeddings, averaged_target_embeddings)
y_pred = np.argmax(sim_matrix, axis=1)

evaluate_performance(data["test"]["label"], y_pred)
# Out:
#                  precision    recall  f1-score   support
#
# Negative Review       0.85      0.84      0.84       533
# Positive Review       0.84      0.85      0.84       533
#
#        accuracy                           0.84      1066
#       macro avg       0.84      0.84      0.84      1066
#    weighted avg       0.84      0.84      0.84      1066

# %%
label_embeddings = model.encode(["A negative review",  "A positive review"])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# 각 문서와 가장 잘 맞는 레이블을 찾습니다.
sim_matrix = cosine_similarity(test_embeddings, label_embeddings)
y_pred = np.argmax(sim_matrix, axis=1)

# %%
evaluate_performance(data["test"]["label"], y_pred)
# Out:
#                  precision    recall  f1-score   support
#
# Negative Review       0.78      0.77      0.78       533
# Positive Review       0.77      0.79      0.78       533
#
#        accuracy                           0.78      1066
#       macro avg       0.78      0.78      0.78      1066
#    weighted avg       0.78      0.78      0.78      1066

# %%
# 모델을 로드합니다.
pipe = pipeline(
    "text2text-generation",
    model="google/flan-t5-small",
    device="cuda:0"
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--google--flan-t5-small/snapshots/0fc9ddf78a1e988dac52e2dac162b0ede4fd74ab/config.json
# Model config T5Config {
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 1024,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 8,
#   "num_heads": 6,
#   "num_layers": 8,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "tie_word_embeddings": false,
#   "transformers_version": "4.53.2",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--google--flan-t5-small/snapshots/0fc9ddf78a1e988dac52e2dac162b0ede4fd74ab/config.json
# Model config T5Config {
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 1024,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 8,
#   "num_heads": 6,
#   "num_layers": 8,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "tie_word_embeddings": false,
#   "transformers_version": "4.53.2",
#   "use_cache": true,
#   "vocab_size": 32128
# }
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--google--flan-t5-small/snapshots/0fc9ddf78a1e988dac52e2dac162b0ede4fd74ab/model.safetensors
# Since the `torch_dtype` attribute can't be found in model's config object, will use torch_dtype={torch_dtype} as derived from model's weights
# Instantiating T5ForConditionalGeneration model under default dtype torch.float32.
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0
# }
#
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at google/flan-t5-small.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--google--flan-t5-small/snapshots/0fc9ddf78a1e988dac52e2dac162b0ede4fd74ab/generation_config.json
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0
# }
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# loading file spiece.model from cache at /root/.cache/huggingface/hub/models--google--flan-t5-small/snapshots/0fc9ddf78a1e988dac52e2dac162b0ede4fd74ab/spiece.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--google--flan-t5-small/snapshots/0fc9ddf78a1e988dac52e2dac162b0ede4fd74ab/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--google--flan-t5-small/snapshots/0fc9ddf78a1e988dac52e2dac162b0ede4fd74ab/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--google--flan-t5-small/snapshots/0fc9ddf78a1e988dac52e2dac162b0ede4fd74ab/tokenizer_config.json
# loading file chat_template.jinja from cache at None
# Device set to use cuda:0

# %%
prompt = "Is the following sentence positive or negative? "
data = data.map(lambda example: {"t5":prompt+example['text']})
data
# Out:
# Map:   0%|          | 0/8530 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1066 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1066 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 't5'],
#         num_rows: 8530
#     })
#     validation: Dataset({
#         features: ['text', 'label', 't5'],
#         num_rows: 1066
#     })
#     test: Dataset({
#         features: ['text', 'label', 't5'],
#         num_rows: 1066
#     })
# })

# %%
y_pred= []
for output in tqdm(pipe(KeyDataset(data["test"], "t5")), total=len(data["test"])):
  text = output[0]["generated_text"]
  y_pred.append(0 if text=="negative" else 1)
# Out:
# 100%|██████████| 1066/1066 [00:55<00:00, 19.04it/s]

# %%
evaluate_performance(data["test"]["label"], y_pred)
# Out:
#                  precision    recall  f1-score   support
#
# Negative Review       0.83      0.85      0.84       533
# Positive Review       0.85      0.83      0.84       533
#
#        accuracy                           0.84      1066
#       macro avg       0.84      0.84      0.84      1066
#    weighted avg       0.84      0.84      0.84      1066

# %%
# !pip install openai==1.55.3 httpx==0.27.2 --force-reinstall --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.6/389.6 kB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.2/352.2 kB 24.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 kB 22.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.7/162.7 kB 10.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# firebase-admin 6.9.0 requires httpx[http2]==0.28.1, but you have httpx 0.27.2 which is incompatible.
# google-genai 1.25.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.

# %%
import openai
from google.colab import userdata
temp_key = userdata.get('GPT')
client = openai.OpenAI(api_key=temp_key)

# %%
def chatgpt_generation(prompt, document, model="gpt-4o-mini"):
    return 1

# %%
# 프롬프트 템플릿을 정의합니다.
prompt = """Predict whether the following document is a positive or negative movie review:

[DOCUMENT]

If it is positive return 1 and if it is negative return 0. Do not give any other answers.
"""

# Predict the target using GPT
document = "unpretentious , charming , quirky , original"
chatgpt_generation(prompt, document)
# Out:
# 1

# %%
import tqdm
predictions = [chatgpt_generation(prompt, doc) for doc in tqdm(data["test"]["text"])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-8-4071543543.py in <cell line: 0>()
#       1 import tqdm
# ----> 2 predictions = [chatgpt_generation(prompt, doc) for doc in tqdm(data["test"]["text"])]
#
# NameError: name 'data' is not defined
